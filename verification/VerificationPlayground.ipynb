# %% [markdown]
# ## Notebook to Run Your Own Networks
# The following section runs all of the set up. This is followed by some starter code where you can fill in the values for your verification.

# %%
from verificationPythonSupport import LocationPropertyPair,SafetyQuery,LivenessQuery,Clause,Property
from verificationPythonSupport import trueAtLocation, trueProperty, falseAtLocation, falseProperty
from startup import runAndDisplay, runAndGet
# %run startup.py

# def runAndDisplay(networkName:str,snapshotName:str,snapshotPath:str,query,show_all=False):
#   --> this will display the results from the query where query is a None, SafetyQuery, or LivenessQuery

# def runAndGet(networkName:str,snapshotName:str,snapshotPath:str,query,show_all=False):
#   --> this will return the pandas object storing the results from the query where query is a None, SafetyQuery, or LivenessQuery
